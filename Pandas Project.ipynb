# %% [markdown]
# # Reading File with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/Bilkis/python/Python Projects/webscrapping projects.csv')
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                                Apple
# 3      4                   UnitedHealth Group
# 4      5                   Berkshire Hathaway
# 5      6                           CVS Health
# 6      7                           ExxonMobil
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                              Cencora
# 10    11                               Costco
# 11    12                       JPMorgan Chase
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                  Chevron Corporation
# 15    16                                Cigna
# 16    17                   Ford Motor Company
# 17    18                      Bank of America
# 18    19                       General Motors
# ...

# %%
pd.set_option('display.max.rows', 100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df.head(20)
# Out:
#     Rank                  Name                        Industry  \
# 0      1               Walmart                          Retail
# 1      2                Amazon      Retail and cloud computing
# 2      3                 Apple            Electronics industry
# 3      4    UnitedHealth Group                      Healthcare
# 4      5    Berkshire Hathaway                    Conglomerate
# 5      6            CVS Health                      Healthcare
# 6      7            ExxonMobil              Petroleum industry
# 7      8              Alphabet  Technology and cloud computing
# 8      9  McKesson Corporation                          Health
# 9     10               Cencora              Pharmacy wholesale
# 10    11                Costco                          Retail
# 11    12        JPMorgan Chase              Financial services
# 12    13             Microsoft  Technology and cloud computing
# 13    14       Cardinal Health                      Healthcare
# ...

# %%
df.tail(20)
# Out:
#     Rank                          Name                 Industry  \
# 80    81          Prudential Financial               Financials
# 81    82                            HP               Technology
# 82    83               United Airlines                  Airline
# 83    84        Performance Food Group          Food processing
# 84    85                   Tyson Foods          Food processing
# 85    86             American Airlines                  Airline
# 86    87                Liberty Mutual                Insurance
# 87    88                          Nike                  Apparel
# 88    89            Oracle Corporation               Technology
# 89    90           Enterprise Products       Petroleum industry
# 90    91         Capital One Financial               Financials
# 91    92  Plains All American Pipeline       Petroleum industry
# 92    93      World Kinect Corporation           Energy trading
# 93    94                           AIG                Insurance
# ...

# %%
df2 = pd.read_csv(r'/Users/Bilkis/Downloads/world_population.csv')

df2
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...
